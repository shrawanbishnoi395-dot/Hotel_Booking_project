# %% [markdown]
# # StayWise
#
# ## Hotel Booking Analytics & Cancellation Prediction
#
# ### Phase 1 : Data Understanding
#
# Author : Sarvan Bishnoi
#
# Objective:
#
# Understand the dataset structure, identify important variables,
# inspect data quality and prepare for data cleaning.
